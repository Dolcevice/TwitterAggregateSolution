# %%
# For twitter API
import tweepy

# For ML
import json
import pandas as pd
import numpy as np

# For Text cleaning
import re
import string
import pickle

# For removing json file
import os

# %%
# Variables for twitter API
MAX_TWEETS = 100
s_query = input("Enter the search query: ")
# Out:
# Enter the search query: cats

# %%
# Auth Keys
API_KEY = 'kEgIQct9vhC3VI81CzA018LCP'
API_KEY_SECRET = 'aWZB24sCd4YmCYJT8EstnPLIJemRinWYQ3SHcR8dnETJlp0RLJ'

ACCESS_TOKEN = '817167849357615104-sTE4VvShmAbxyVNOFqdngfu8pl1onRT'
ACCESS_TOKEN_SECRET = '14MlBjPpNUy1IjFpv7RwksgJTOae6DVlac8fNbduY9S9E'

# %%
# Create API

# Authentication
auth = tweepy.OAuthHandler(API_KEY, API_KEY_SECRET)
auth.set_access_token(ACCESS_TOKEN, ACCESS_TOKEN_SECRET)
    
api = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True, 
                 compression=True)

# %%
# Create Cursor
search_cursor = tweepy.Cursor(api.search, q=s_query, lang='en').items(MAX_TWEETS)

# %%
# Export JSON
for tweet in search_cursor:
    with open('tweet_dump.json', 'a') as file:
        file.write(json.dumps(tweet._json))
        file.write('\n')

# %%
# Create a dataframe
tweet_df = pd.read_json('tweet_dump.json', lines=True)

# %%
# Read the dataframe
tweet_df.head(10)
# Out:
#    contributors  coordinates          created_at  \
# 0           NaN          NaN 2019-02-04 15:56:51
# 1           NaN          NaN 2019-02-04 15:56:50
# 2           NaN          NaN 2019-02-04 15:56:50
# 3           NaN          NaN 2019-02-04 15:56:45
# 4           NaN          NaN 2019-02-04 15:56:43
# 5           NaN          NaN 2019-02-04 15:56:42
# 6           NaN          NaN 2019-02-04 15:56:29
# 7           NaN          NaN 2019-02-04 15:56:27
# 8           NaN          NaN 2019-02-04 15:56:27
# 9           NaN          NaN 2019-02-04 15:56:25
#
#                                             entities  \
# 0  {'hashtags': [{'text': 'Buckets', 'indices': [...
# 1  {'hashtags': [], 'symbols': [], 'user_mentions...
# 2  {'hashtags': [], 'symbols': [], 'user_mentions...
# 3  {'hashtags': [], 'symbols': [], 'user_mentions...
# 4  {'hashtags': [], 'symbols': [], 'user_mentions...
# 5  {'hashtags': [], 'symbols': [], 'user_mentions...
# 6  {'hashtags': [], 'symbols': [], 'user_mentions...
# 7  {'hashtags': [], 'symbols': [], 'user_mentions...
# 8  {'hashtags': [], 'symbols': [], 'user_mentions...
# 9  {'hashtags': [], 'symbols': [], 'user_mentions...
#
#                                    extended_entities  favorite_count  \
# 0                                                NaN               0
# 1                                                NaN               0
# 2                                                NaN               0
# 3                                                NaN               0
# 4  {'media': [{'id': 1092142093579874305, 'id_str...               0
# 5                                                NaN               0
# 6                                                NaN               0
# 7  {'media': [{'id': 1092451815612993537, 'id_str...               0
# 8                                                NaN               0
# 9  {'media': [{'id': 1092165833399316481, 'id_str...               0
#
#    favorited  geo                   id               id_str  ...  \
# 0      False  NaN  1092451929102475265  1092451929102475264  ...
# 1      False  NaN  1092451927495831552  1092451927495831552  ...
# 2      False  NaN  1092451926548066307  1092451926548066304  ...
# 3      False  NaN  1092451906222505986  1092451906222505984  ...
# 4      False  NaN  1092451897171210240  1092451897171210240  ...
# 5      False  NaN  1092451890967629824  1092451890967629824  ...
# 6      False  NaN  1092451839272841216  1092451839272841216  ...
# 7      False  NaN  1092451830519513088  1092451830519513088  ...
# 8      False  NaN  1092451828808273920  1092451828808273920  ...
# 9      False  NaN  1092451819492597761  1092451819492597760  ...
#
#                                        quoted_status  quoted_status_id  \
# 0  {'created_at': 'Mon Feb 04 15:47:57 +0000 2019...      1.092450e+18
# 1                                                NaN               NaN
# 2                                                NaN               NaN
# 3                                                NaN               NaN
# 4                                                NaN               NaN
# 5                                                NaN               NaN
# 6                                                NaN               NaN
# 7                                                NaN               NaN
# 8                                                NaN      1.092240e+18
# 9                                                NaN               NaN
#
#    quoted_status_id_str  retweet_count  retweeted  \
# 0          1.092450e+18              0      False
# 1                   NaN              0      False
# 2                   NaN           4334      False
# 3                   NaN             13      False
# 4                   NaN           1554      False
# 5                   NaN              0      False
# 6                   NaN           4188      False
# 7                   NaN              0      False
# 8          1.092240e+18             18      False
# 9                   NaN             25      False
#
#                                     retweeted_status  \
# 0                                                NaN
# 1                                                NaN
# 2  {'created_at': 'Mon Nov 02 19:58:35 +0000 2015...
# 3  {'created_at': 'Mon Feb 04 13:55:06 +0000 2019...
# 4  {'created_at': 'Sun Feb 03 19:26:13 +0000 2019...
# 5                                                NaN
# 6  {'created_at': 'Sat Feb 02 16:48:01 +0000 2019...
# 7                                                NaN
# 8  {'created_at': 'Mon Feb 04 02:03:24 +0000 2019...
# 9  {'created_at': 'Sun Feb 03 21:00:04 +0000 2019...
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/android" ...
# 2  <a href="http://twitter.com/#!/download/ipad" ...
# 3  <a href="http://twitter.com/download/android" ...
# 4  <a href="http://twitter.com" rel="nofollow">Tw...
# 5  <a href="http://twitter.com" rel="nofollow">Tw...
# 6  <a href="http://twitter.com/download/android" ...
# 7  <a href="http://twitter.com/download/iphone" r...
# 8  <a href="http://twitter.com/download/iphone" r...
# 9  <a href="http://twitter.com/download/android" ...
#
#                                                 text truncated  \
# 0  One of my favorite Cats of the Cal era!!! #Buc...     False
# 1  @5sosas_cats @Luke5SOS @5SOS I just wanna touc...     False
# 2  RT @BradChacos: Cats aren't as useless as ever...     False
# 3  RT @Sotherans: Bibliophiliophile (noun): an un...     False
# 4  RT @clcish: cats before throwing up a hair bal...     False
# 5      Do you know dogs and cats keep following you?     False
# 6  RT @animalspng: retweet if you\nreally\n  real...     False
# 7  My two cats don’t get alone. I took this while...     False
# 8        RT @ylreajd: @ cats https://t.co/2xa2QMx7Wl     False
# 9  RT @Moguritheracoon: So there are 3 cats... An...     False
#
#                                                 user
# 0  {'id': 35261850, 'id_str': '35261850', 'name':...
# 1  {'id': 1022189989617000448, 'id_str': '1022189...
# 2  {'id': 41407090, 'id_str': '41407090', 'name':...
# 3  {'id': 1052965325682237440, 'id_str': '1052965...
# 4  {'id': 1036320263330258945, 'id_str': '1036320...
# 5  {'id': 1899002628, 'id_str': '1899002628', 'na...
# 6  {'id': 1000409610514132992, 'id_str': '1000409...
# 7  {'id': 911636072081362948, 'id_str': '91163607...
# 8  {'id': 2756068606, 'id_str': '2756068606', 'na...
# 9  {'id': 1053701280202280961, 'id_str': '1053701...
#
# [10 rows x 30 columns]

# %%
clean_df = tweet_df.drop(['contributors','coordinates','entities','extended_entities', 'favorited', 'geo', 'id', 'id_str','in_reply_to_screen_name','in_reply_to_status_id'
              ,'in_reply_to_status_id_str', 'in_reply_to_user_id','in_reply_to_user_id_str', 'is_quote_status', 'possibly_sensitive', 'quoted_status','quoted_status_id', 
               'quoted_status_id_str', 'retweeted', 'source', 'user', 'place','retweeted_status'], axis = 1)

# %%
clean_df.sort_values(by = ['retweet_count'], ascending=False)
# Out:
#             created_at  favorite_count lang  \
# 91 2019-02-04 15:54:17               0   en
# 41 2019-02-04 15:55:50               0   en
# 19 2019-02-04 15:56:14               0   en
# 38 2019-02-04 15:55:52               0   en
# 88 2019-02-04 15:54:20               0   en
# 85 2019-02-04 15:54:24               0   en
# 2  2019-02-04 15:56:50               0   en
# 6  2019-02-04 15:56:29               0   en
# 54 2019-02-04 15:55:22               0   en
# 12 2019-02-04 15:56:22               0   en
# 4  2019-02-04 15:56:43               0   en
# 80 2019-02-04 15:54:32               0   en
# 57 2019-02-04 15:55:17               0   en
# 83 2019-02-04 15:54:27               0   en
# 20 2019-02-04 15:56:12               0   en
# 63 2019-02-04 15:55:01               0   en
# 24 2019-02-04 15:56:07               0   en
# 46 2019-02-04 15:55:43               0   en
# 68 2019-02-04 15:54:55               0   en
# 81 2019-02-04 15:54:32               0   en
# 93 2019-02-04 15:54:16               0   en
# 39 2019-02-04 15:55:51               0   en
# 45 2019-02-04 15:55:43               0   en
# 76 2019-02-04 15:54:44               0   en
# 22 2019-02-04 15:56:10               0   en
# 86 2019-02-04 15:54:20               0   en
# 82 2019-02-04 15:54:28               0   en
# 71 2019-02-04 15:54:50               0   en
# 53 2019-02-04 15:55:24               0   en
# 87 2019-02-04 15:54:20               0   en
# ..                 ...             ...  ...
# 50 2019-02-04 15:55:31               0   en
# 69 2019-02-04 15:54:52               0   en
# 27 2019-02-04 15:56:03               0   en
# 5  2019-02-04 15:56:42               0   en
# 7  2019-02-04 15:56:27               0   en
# 10 2019-02-04 15:56:24               0   en
# 11 2019-02-04 15:56:23               0   en
# 13 2019-02-04 15:56:21               0   en
# 14 2019-02-04 15:56:20               0   en
# 15 2019-02-04 15:56:20               0   en
# 16 2019-02-04 15:56:20               0   en
# 17 2019-02-04 15:56:18               2   en
# 18 2019-02-04 15:56:17               0   en
# 21 2019-02-04 15:56:12               0   en
# 25 2019-02-04 15:56:05               0   en
# 30 2019-02-04 15:56:00               0   en
# 65 2019-02-04 15:55:00               0   en
# 31 2019-02-04 15:56:00               0   en
# 34 2019-02-04 15:55:57               0   en
# 35 2019-02-04 15:55:56               0   en
# 37 2019-02-04 15:55:54               0   en
# 40 2019-02-04 15:55:51               0   en
# 42 2019-02-04 15:55:50               0   en
# 47 2019-02-04 15:55:37               0   en
# 1  2019-02-04 15:56:50               0   en
# 56 2019-02-04 15:55:18               1   en
# 60 2019-02-04 15:55:10               0   en
# 62 2019-02-04 15:55:04               0   en
# 64 2019-02-04 15:55:01               1   en
# 99 2019-02-04 15:54:07               0   en
#
#                                              metadata  retweet_count  \
# 91  {'iso_language_code': 'en', 'result_type': 're...          22186
# 41  {'iso_language_code': 'en', 'result_type': 're...          18081
# 19  {'iso_language_code': 'en', 'result_type': 're...          14147
# 38  {'iso_language_code': 'en', 'result_type': 're...          13943
# 88  {'iso_language_code': 'en', 'result_type': 're...           5447
# 85  {'iso_language_code': 'en', 'result_type': 're...           5447
# 2   {'iso_language_code': 'en', 'result_type': 're...           4334
# 6   {'iso_language_code': 'en', 'result_type': 're...           4188
# 54  {'iso_language_code': 'en', 'result_type': 're...           1554
# 12  {'iso_language_code': 'en', 'result_type': 're...           1554
# 4   {'iso_language_code': 'en', 'result_type': 're...           1554
# 80  {'iso_language_code': 'en', 'result_type': 're...           1343
# 57  {'iso_language_code': 'en', 'result_type': 're...           1343
# 83  {'iso_language_code': 'en', 'result_type': 're...            533
# 20  {'iso_language_code': 'en', 'result_type': 're...            533
# 63  {'iso_language_code': 'en', 'result_type': 're...            533
# 24  {'iso_language_code': 'en', 'result_type': 're...            526
# 46  {'iso_language_code': 'en', 'result_type': 're...            340
# 68  {'iso_language_code': 'en', 'result_type': 're...            314
# 81  {'iso_language_code': 'en', 'result_type': 're...            314
# 93  {'iso_language_code': 'en', 'result_type': 're...            264
# 39  {'iso_language_code': 'en', 'result_type': 're...            264
# 45  {'iso_language_code': 'en', 'result_type': 're...            264
# 76  {'iso_language_code': 'en', 'result_type': 're...            264
# 22  {'iso_language_code': 'en', 'result_type': 're...            180
# 86  {'iso_language_code': 'en', 'result_type': 're...            116
# 82  {'iso_language_code': 'en', 'result_type': 're...             99
# 71  {'iso_language_code': 'en', 'result_type': 're...             97
# 53  {'iso_language_code': 'en', 'result_type': 're...             80
# 87  {'iso_language_code': 'en', 'result_type': 're...             70
# ..                                                ...            ...
# 50  {'iso_language_code': 'en', 'result_type': 're...              0
# 69  {'iso_language_code': 'en', 'result_type': 're...              0
# 27  {'iso_language_code': 'en', 'result_type': 're...              0
# 5   {'iso_language_code': 'en', 'result_type': 're...              0
# 7   {'iso_language_code': 'en', 'result_type': 're...              0
# 10  {'iso_language_code': 'en', 'result_type': 're...              0
# 11  {'iso_language_code': 'en', 'result_type': 're...              0
# 13  {'iso_language_code': 'en', 'result_type': 're...              0
# 14  {'iso_language_code': 'en', 'result_type': 're...              0
# 15  {'iso_language_code': 'en', 'result_type': 're...              0
# 16  {'iso_language_code': 'en', 'result_type': 're...              0
# 17  {'iso_language_code': 'en', 'result_type': 're...              0
# 18  {'iso_language_code': 'en', 'result_type': 're...              0
# 21  {'iso_language_code': 'en', 'result_type': 're...              0
# 25  {'iso_language_code': 'en', 'result_type': 're...              0
# 30  {'iso_language_code': 'en', 'result_type': 're...              0
# 65  {'iso_language_code': 'en', 'result_type': 're...              0
# 31  {'iso_language_code': 'en', 'result_type': 're...              0
# 34  {'iso_language_code': 'en', 'result_type': 're...              0
# 35  {'iso_language_code': 'en', 'result_type': 're...              0
# 37  {'iso_language_code': 'en', 'result_type': 're...              0
# 40  {'iso_language_code': 'en', 'result_type': 're...              0
# 42  {'iso_language_code': 'en', 'result_type': 're...              0
# 47  {'iso_language_code': 'en', 'result_type': 're...              0
# 1   {'iso_language_code': 'en', 'result_type': 're...              0
# 56  {'iso_language_code': 'en', 'result_type': 're...              0
# 60  {'iso_language_code': 'en', 'result_type': 're...              0
# 62  {'iso_language_code': 'en', 'result_type': 're...              0
# 64  {'iso_language_code': 'en', 'result_type': 're...              0
# 99  {'iso_language_code': 'en', 'result_type': 're...              0
#
#                                                  text  truncated
# 91  RT @AMAZlNGNATURE: Be the guy who plays the pi...      False
# 41  RT @fluff: stop what you're doing immediately ...      False
# 19  RT @imskytrash: nobody:\n\ncats:\n   __/  /\n/...      False
# 38  RT @dodo: Cats vs. world 😼 https://t.co/HtD3Vk...      False
# 88  RT @AleZ2016: A heartbreaking photo of a dog w...      False
# 85  RT @AleZ2016: A heartbreaking photo of a dog w...      False
# 2   RT @BradChacos: Cats aren't as useless as ever...      False
# 6   RT @animalspng: retweet if you\nreally\n  real...      False
# 54  RT @clcish: cats before throwing up a hair bal...      False
# 12  RT @clcish: cats before throwing up a hair bal...      False
# 4   RT @clcish: cats before throwing up a hair bal...      False
# 80  RT @Ironhorse76: By a super-majority a celebra...      False
# 57  RT @Ironhorse76: By a super-majority a celebra...      False
# 83  RT @TheWorldOfFunny: Cats are in a world of th...      False
# 20  RT @TheWorldOfFunny: Cats are in a world of th...      False
# 63  RT @TheWorldOfFunny: Cats are in a world of th...      False
# 24    RT @sloboah: hover cats https://t.co/3hscOGE0Kv      False
# 46  RT @PurinaCatChow: #Our4WordFuture Cats. Oh, a...      False
# 68  RT @dumpstercryptid: adult black dogs &amp; ca...      False
# 81  RT @dumpstercryptid: adult black dogs &amp; ca...      False
# 93  RT @leejenoo: lele: lunar new year! (seolnal 설...      False
# 39  RT @leejenoo: lele: lunar new year! (seolnal 설...      False
# 45  RT @leejenoo: lele: lunar new year! (seolnal 설...      False
# 76  RT @leejenoo: lele: lunar new year! (seolnal 설...      False
# 22  RT @aproko_doctor: A dog with cancer in the US...      False
# 86  RT @WynneGuglielmo: 😱😭😤This is just one of 56+...      False
# 82  RT @reinosoj2: Thankfully we don't rely just o...      False
# 71  RT @nicoleee_veee: Theory: @taylorswift13 isn’...      False
# 53  RT @ColeTheBlackCat: "The bond between animals...      False
# 87  RT @DavidBegnaud: ‘Spayathon’ is happening tod...      False
# ..                                                ...        ...
# 50  Did you know the animal members of your family...       True
# 69  I ran out of canned food for the cats. My inju...      False
# 27  https://t.co/P68hBcHbt2 \nA princely loaf \n#C...       True
# 5       Do you know dogs and cats keep following you?      False
# 7   My two cats don’t get alone. I took this while...      False
# 10            Do you know dogs and cats keep staring?      False
# 11  Pet Carrier for Dogs Cats Airline Approved Tra...      False
# 13  I love pussy cats. Why are you staring at me l...      False
# 14                                               cats      False
# 15                                      Cats are dope      False
# 16          Do you know dogs and cats keep following?      False
# 17  Cats everywhere 😂😂🐱🐱\n\n#ARMYSelcaDay https://...      False
# 18  My mom really took my dogs blanket and told me...      False
# 21             @DarthLux Playing with Cats))) Datings      False
# 25  @HollyCabot I told my mom she should set up an...       True
# 30  @RobinHousemate The cats on twitter are the be...      False
# 65  @dodgema Thanks, but it’s not bad. Of course, ...      False
# 31  So excited to launch my ks!! For a second i th...      False
# 34  Prepper Supplies for Your Cats https://t.co/Zi...      False
# 35  So it's been a few weeks since I've been singl...       True
# 37  Cats are really so adorable. They’re cuddly an...       True
# 40  @SummerrSoldier I mean the “So, you like cats”...      False
# 42  @videocats Cats are has bad ahort sight and re...      False
# 47                               i miss those cats :(      False
# 1   @5sosas_cats @Luke5SOS @5SOS I just wanna touc...      False
# 56  #HappyMonday \nI know a lot of people post gif...       True
# 60      i wish i had cats to fill this loneliness :")      False
# 62  https://t.co/SVoBhfAe8E \nMy boy Buttons is a ...       True
# 64  In case you missed it, Cats are Liquid is (fin...      False
# 99                              cats make me so happy      False
#
# [100 rows x 7 columns]

# %%
clean_df.drop_duplicates(subset='text', keep='first', inplace=True)

# %%
clean_df.sort_values(by = ['retweet_count'], ascending=False)
# Out:
#             created_at  favorite_count lang  \
# 91 2019-02-04 15:54:17               0   en
# 41 2019-02-04 15:55:50               0   en
# 19 2019-02-04 15:56:14               0   en
# 38 2019-02-04 15:55:52               0   en
# 85 2019-02-04 15:54:24               0   en
# 2  2019-02-04 15:56:50               0   en
# 6  2019-02-04 15:56:29               0   en
# 4  2019-02-04 15:56:43               0   en
# 57 2019-02-04 15:55:17               0   en
# 20 2019-02-04 15:56:12               0   en
# 24 2019-02-04 15:56:07               0   en
# 46 2019-02-04 15:55:43               0   en
# 68 2019-02-04 15:54:55               0   en
# 39 2019-02-04 15:55:51               0   en
# 22 2019-02-04 15:56:10               0   en
# 86 2019-02-04 15:54:20               0   en
# 82 2019-02-04 15:54:28               0   en
# 71 2019-02-04 15:54:50               0   en
# 53 2019-02-04 15:55:24               0   en
# 87 2019-02-04 15:54:20               0   en
# 77 2019-02-04 15:54:42               0   en
# 73 2019-02-04 15:54:48               0   en
# 58 2019-02-04 15:55:17               0   en
# 94 2019-02-04 15:54:15               0   en
# 9  2019-02-04 15:56:25               0   en
# 74 2019-02-04 15:54:47               0   en
# 48 2019-02-04 15:55:35               0   en
# 32 2019-02-04 15:55:58               0   en
# 8  2019-02-04 15:56:27               0   en
# 3  2019-02-04 15:56:45               0   en
# ..                 ...             ...  ...
# 79 2019-02-04 15:54:38               0   en
# 47 2019-02-04 15:55:37               0   en
# 65 2019-02-04 15:55:00               0   en
# 64 2019-02-04 15:55:01               1   en
# 5  2019-02-04 15:56:42               0   en
# 7  2019-02-04 15:56:27               0   en
# 10 2019-02-04 15:56:24               0   en
# 11 2019-02-04 15:56:23               0   en
# 13 2019-02-04 15:56:21               0   en
# 14 2019-02-04 15:56:20               0   en
# 15 2019-02-04 15:56:20               0   en
# 16 2019-02-04 15:56:20               0   en
# 17 2019-02-04 15:56:18               2   en
# 18 2019-02-04 15:56:17               0   en
# 21 2019-02-04 15:56:12               0   en
# 25 2019-02-04 15:56:05               0   en
# 27 2019-02-04 15:56:03               0   en
# 30 2019-02-04 15:56:00               0   en
# 31 2019-02-04 15:56:00               0   en
# 34 2019-02-04 15:55:57               0   en
# 35 2019-02-04 15:55:56               0   en
# 37 2019-02-04 15:55:54               0   en
# 40 2019-02-04 15:55:51               0   en
# 42 2019-02-04 15:55:50               0   en
# 1  2019-02-04 15:56:50               0   en
# 50 2019-02-04 15:55:31               0   en
# 56 2019-02-04 15:55:18               1   en
# 60 2019-02-04 15:55:10               0   en
# 62 2019-02-04 15:55:04               0   en
# 99 2019-02-04 15:54:07               0   en
#
#                                              metadata  retweet_count  \
# 91  {'iso_language_code': 'en', 'result_type': 're...          22186
# 41  {'iso_language_code': 'en', 'result_type': 're...          18081
# 19  {'iso_language_code': 'en', 'result_type': 're...          14147
# 38  {'iso_language_code': 'en', 'result_type': 're...          13943
# 85  {'iso_language_code': 'en', 'result_type': 're...           5447
# 2   {'iso_language_code': 'en', 'result_type': 're...           4334
# 6   {'iso_language_code': 'en', 'result_type': 're...           4188
# 4   {'iso_language_code': 'en', 'result_type': 're...           1554
# 57  {'iso_language_code': 'en', 'result_type': 're...           1343
# 20  {'iso_language_code': 'en', 'result_type': 're...            533
# 24  {'iso_language_code': 'en', 'result_type': 're...            526
# 46  {'iso_language_code': 'en', 'result_type': 're...            340
# 68  {'iso_language_code': 'en', 'result_type': 're...            314
# 39  {'iso_language_code': 'en', 'result_type': 're...            264
# 22  {'iso_language_code': 'en', 'result_type': 're...            180
# 86  {'iso_language_code': 'en', 'result_type': 're...            116
# 82  {'iso_language_code': 'en', 'result_type': 're...             99
# 71  {'iso_language_code': 'en', 'result_type': 're...             97
# 53  {'iso_language_code': 'en', 'result_type': 're...             80
# 87  {'iso_language_code': 'en', 'result_type': 're...             70
# 77  {'iso_language_code': 'en', 'result_type': 're...             39
# 73  {'iso_language_code': 'en', 'result_type': 're...             30
# 58  {'iso_language_code': 'en', 'result_type': 're...             30
# 94  {'iso_language_code': 'en', 'result_type': 're...             29
# 9   {'iso_language_code': 'en', 'result_type': 're...             25
# 74  {'iso_language_code': 'en', 'result_type': 're...             22
# 48  {'iso_language_code': 'en', 'result_type': 're...             19
# 32  {'iso_language_code': 'en', 'result_type': 're...             19
# 8   {'iso_language_code': 'en', 'result_type': 're...             18
# 3   {'iso_language_code': 'en', 'result_type': 're...             13
# ..                                                ...            ...
# 79  {'iso_language_code': 'en', 'result_type': 're...              0
# 47  {'iso_language_code': 'en', 'result_type': 're...              0
# 65  {'iso_language_code': 'en', 'result_type': 're...              0
# 64  {'iso_language_code': 'en', 'result_type': 're...              0
# 5   {'iso_language_code': 'en', 'result_type': 're...              0
# 7   {'iso_language_code': 'en', 'result_type': 're...              0
# 10  {'iso_language_code': 'en', 'result_type': 're...              0
# 11  {'iso_language_code': 'en', 'result_type': 're...              0
# 13  {'iso_language_code': 'en', 'result_type': 're...              0
# 14  {'iso_language_code': 'en', 'result_type': 're...              0
# 15  {'iso_language_code': 'en', 'result_type': 're...              0
# 16  {'iso_language_code': 'en', 'result_type': 're...              0
# 17  {'iso_language_code': 'en', 'result_type': 're...              0
# 18  {'iso_language_code': 'en', 'result_type': 're...              0
# 21  {'iso_language_code': 'en', 'result_type': 're...              0
# 25  {'iso_language_code': 'en', 'result_type': 're...              0
# 27  {'iso_language_code': 'en', 'result_type': 're...              0
# 30  {'iso_language_code': 'en', 'result_type': 're...              0
# 31  {'iso_language_code': 'en', 'result_type': 're...              0
# 34  {'iso_language_code': 'en', 'result_type': 're...              0
# 35  {'iso_language_code': 'en', 'result_type': 're...              0
# 37  {'iso_language_code': 'en', 'result_type': 're...              0
# 40  {'iso_language_code': 'en', 'result_type': 're...              0
# 42  {'iso_language_code': 'en', 'result_type': 're...              0
# 1   {'iso_language_code': 'en', 'result_type': 're...              0
# 50  {'iso_language_code': 'en', 'result_type': 're...              0
# 56  {'iso_language_code': 'en', 'result_type': 're...              0
# 60  {'iso_language_code': 'en', 'result_type': 're...              0
# 62  {'iso_language_code': 'en', 'result_type': 're...              0
# 99  {'iso_language_code': 'en', 'result_type': 're...              0
#
#                                                  text  truncated
# 91  RT @AMAZlNGNATURE: Be the guy who plays the pi...      False
# 41  RT @fluff: stop what you're doing immediately ...      False
# 19  RT @imskytrash: nobody:\n\ncats:\n   __/  /\n/...      False
# 38  RT @dodo: Cats vs. world 😼 https://t.co/HtD3Vk...      False
# 85  RT @AleZ2016: A heartbreaking photo of a dog w...      False
# 2   RT @BradChacos: Cats aren't as useless as ever...      False
# 6   RT @animalspng: retweet if you\nreally\n  real...      False
# 4   RT @clcish: cats before throwing up a hair bal...      False
# 57  RT @Ironhorse76: By a super-majority a celebra...      False
# 20  RT @TheWorldOfFunny: Cats are in a world of th...      False
# 24    RT @sloboah: hover cats https://t.co/3hscOGE0Kv      False
# 46  RT @PurinaCatChow: #Our4WordFuture Cats. Oh, a...      False
# 68  RT @dumpstercryptid: adult black dogs &amp; ca...      False
# 39  RT @leejenoo: lele: lunar new year! (seolnal 설...      False
# 22  RT @aproko_doctor: A dog with cancer in the US...      False
# 86  RT @WynneGuglielmo: 😱😭😤This is just one of 56+...      False
# 82  RT @reinosoj2: Thankfully we don't rely just o...      False
# 71  RT @nicoleee_veee: Theory: @taylorswift13 isn’...      False
# 53  RT @ColeTheBlackCat: "The bond between animals...      False
# 87  RT @DavidBegnaud: ‘Spayathon’ is happening tod...      False
# 77  RT @catswithnohope: PREGNANT MOMMA KITTY\nI ha...      False
# 73  RT @PetLoveers: 👉 Follow @petloveers 🐱 \n#cat ...      False
# 58  RT @WildeOscarCat: #MONDAY #DEATHROW RT@Sandra...      False
# 94  RT @FedererKate: Please support Javier his fam...      False
# 9   RT @Moguritheracoon: So there are 3 cats... An...      False
# 74  RT @butterflygone02: 🆘🆘🆘🆘🐈💔🐕🚨🚨🚨🚨\nREQUEST RTS ...      False
# 48  RT @HoudiniDancing: PLAYING AND FLIPPING! Hope...      False
# 32  RT @Misamosquito: An AU in which Momo befriend...      False
# 8         RT @ylreajd: @ cats https://t.co/2xa2QMx7Wl      False
# 3   RT @Sotherans: Bibliophiliophile (noun): an un...      False
# ..                                                ...        ...
# 79  @therealelp dude, I read that, immediately sre...       True
# 47                               i miss those cats :(      False
# 65  @dodgema Thanks, but it’s not bad. Of course, ...      False
# 64  In case you missed it, Cats are Liquid is (fin...      False
# 5       Do you know dogs and cats keep following you?      False
# 7   My two cats don’t get alone. I took this while...      False
# 10            Do you know dogs and cats keep staring?      False
# 11  Pet Carrier for Dogs Cats Airline Approved Tra...      False
# 13  I love pussy cats. Why are you staring at me l...      False
# 14                                               cats      False
# 15                                      Cats are dope      False
# 16          Do you know dogs and cats keep following?      False
# 17  Cats everywhere 😂😂🐱🐱\n\n#ARMYSelcaDay https://...      False
# 18  My mom really took my dogs blanket and told me...      False
# 21             @DarthLux Playing with Cats))) Datings      False
# 25  @HollyCabot I told my mom she should set up an...       True
# 27  https://t.co/P68hBcHbt2 \nA princely loaf \n#C...       True
# 30  @RobinHousemate The cats on twitter are the be...      False
# 31  So excited to launch my ks!! For a second i th...      False
# 34  Prepper Supplies for Your Cats https://t.co/Zi...      False
# 35  So it's been a few weeks since I've been singl...       True
# 37  Cats are really so adorable. They’re cuddly an...       True
# 40  @SummerrSoldier I mean the “So, you like cats”...      False
# 42  @videocats Cats are has bad ahort sight and re...      False
# 1   @5sosas_cats @Luke5SOS @5SOS I just wanna touc...      False
# 50  Did you know the animal members of your family...       True
# 56  #HappyMonday \nI know a lot of people post gif...       True
# 60      i wish i had cats to fill this loneliness :")      False
# 62  https://t.co/SVoBhfAe8E \nMy boy Buttons is a ...       True
# 99                              cats make me so happy      False
#
# [90 rows x 7 columns]

# %%
# Remove all trailing spaces and punctuation
clean_df.columns.str.rstrip('.!? \n\t')
# Remove all newlines
clean_df.replace('\n', '', regex=True, inplace=True)
# Remove all twitter media links
clean_df.replace('tco.{10}', '', regex=True, inplace=True)
clean_df.replace('tco', '', regex=True, inplace=True)
clean_df.replace('https:.{13}', '', regex=True, inplace=True)
clean_df.replace('https:', '', regex=True, inplace=True)
# Remove all extra punctuations
clean_df.replace('[,\.!?/|_]', '', regex=True, inplace=True)
# Remove retweet marks
clean_df.replace(r'RT.*:', '', regex=True, inplace=True)
clean_df.replace(r'\b\w{1,2}\b', '', regex=True, inplace=True)
clean_df.replace('@.* \s', '', regex=True, inplace=True)


# Show sorted values
clean_df.sort_values(by = ['retweet_count'], ascending=False)
# Out:
#             created_at  favorite_count lang  \
# 91 2019-02-04 15:54:17               0
# 41 2019-02-04 15:55:50               0
# 19 2019-02-04 15:56:14               0
# 38 2019-02-04 15:55:52               0
# 85 2019-02-04 15:54:24               0
# 2  2019-02-04 15:56:50               0
# 6  2019-02-04 15:56:29               0
# 4  2019-02-04 15:56:43               0
# 57 2019-02-04 15:55:17               0
# 20 2019-02-04 15:56:12               0
# 24 2019-02-04 15:56:07               0
# 46 2019-02-04 15:55:43               0
# 68 2019-02-04 15:54:55               0
# 39 2019-02-04 15:55:51               0
# 22 2019-02-04 15:56:10               0
# 86 2019-02-04 15:54:20               0
# 82 2019-02-04 15:54:28               0
# 71 2019-02-04 15:54:50               0
# 53 2019-02-04 15:55:24               0
# 87 2019-02-04 15:54:20               0
# 77 2019-02-04 15:54:42               0
# 73 2019-02-04 15:54:48               0
# 58 2019-02-04 15:55:17               0
# 94 2019-02-04 15:54:15               0
# 9  2019-02-04 15:56:25               0
# 74 2019-02-04 15:54:47               0
# 48 2019-02-04 15:55:35               0
# 32 2019-02-04 15:55:58               0
# 8  2019-02-04 15:56:27               0
# 3  2019-02-04 15:56:45               0
# ..                 ...             ...  ...
# 79 2019-02-04 15:54:38               0
# 47 2019-02-04 15:55:37               0
# 65 2019-02-04 15:55:00               0
# 64 2019-02-04 15:55:01               1
# 5  2019-02-04 15:56:42               0
# 7  2019-02-04 15:56:27               0
# 10 2019-02-04 15:56:24               0
# 11 2019-02-04 15:56:23               0
# 13 2019-02-04 15:56:21               0
# 14 2019-02-04 15:56:20               0
# 15 2019-02-04 15:56:20               0
# 16 2019-02-04 15:56:20               0
# 17 2019-02-04 15:56:18               2
# 18 2019-02-04 15:56:17               0
# 21 2019-02-04 15:56:12               0
# 25 2019-02-04 15:56:05               0
# 27 2019-02-04 15:56:03               0
# 30 2019-02-04 15:56:00               0
# 31 2019-02-04 15:56:00               0
# 34 2019-02-04 15:55:57               0
# 35 2019-02-04 15:55:56               0
# 37 2019-02-04 15:55:54               0
# 40 2019-02-04 15:55:51               0
# 42 2019-02-04 15:55:50               0
# 1  2019-02-04 15:56:50               0
# 50 2019-02-04 15:55:31               0
# 56 2019-02-04 15:55:18               1
# 60 2019-02-04 15:55:10               0
# 62 2019-02-04 15:55:04               0
# 99 2019-02-04 15:54:07               0
#
#                                              metadata  retweet_count  \
# 91  {'iso_language_code': 'en', 'result_type': 're...          22186
# 41  {'iso_language_code': 'en', 'result_type': 're...          18081
# 19  {'iso_language_code': 'en', 'result_type': 're...          14147
# 38  {'iso_language_code': 'en', 'result_type': 're...          13943
# 85  {'iso_language_code': 'en', 'result_type': 're...           5447
# 2   {'iso_language_code': 'en', 'result_type': 're...           4334
# 6   {'iso_language_code': 'en', 'result_type': 're...           4188
# 4   {'iso_language_code': 'en', 'result_type': 're...           1554
# 57  {'iso_language_code': 'en', 'result_type': 're...           1343
# 20  {'iso_language_code': 'en', 'result_type': 're...            533
# 24  {'iso_language_code': 'en', 'result_type': 're...            526
# 46  {'iso_language_code': 'en', 'result_type': 're...            340
# 68  {'iso_language_code': 'en', 'result_type': 're...            314
# 39  {'iso_language_code': 'en', 'result_type': 're...            264
# 22  {'iso_language_code': 'en', 'result_type': 're...            180
# 86  {'iso_language_code': 'en', 'result_type': 're...            116
# 82  {'iso_language_code': 'en', 'result_type': 're...             99
# 71  {'iso_language_code': 'en', 'result_type': 're...             97
# 53  {'iso_language_code': 'en', 'result_type': 're...             80
# 87  {'iso_language_code': 'en', 'result_type': 're...             70
# 77  {'iso_language_code': 'en', 'result_type': 're...             39
# 73  {'iso_language_code': 'en', 'result_type': 're...             30
# 58  {'iso_language_code': 'en', 'result_type': 're...             30
# 94  {'iso_language_code': 'en', 'result_type': 're...             29
# 9   {'iso_language_code': 'en', 'result_type': 're...             25
# 74  {'iso_language_code': 'en', 'result_type': 're...             22
# 48  {'iso_language_code': 'en', 'result_type': 're...             19
# 32  {'iso_language_code': 'en', 'result_type': 're...             19
# 8   {'iso_language_code': 'en', 'result_type': 're...             18
# 3   {'iso_language_code': 'en', 'result_type': 're...             13
# ..                                                ...            ...
# 79  {'iso_language_code': 'en', 'result_type': 're...              0
# 47  {'iso_language_code': 'en', 'result_type': 're...              0
# 65  {'iso_language_code': 'en', 'result_type': 're...              0
# 64  {'iso_language_code': 'en', 'result_type': 're...              0
# 5   {'iso_language_code': 'en', 'result_type': 're...              0
# 7   {'iso_language_code': 'en', 'result_type': 're...              0
# 10  {'iso_language_code': 'en', 'result_type': 're...              0
# 11  {'iso_language_code': 'en', 'result_type': 're...              0
# 13  {'iso_language_code': 'en', 'result_type': 're...              0
# 14  {'iso_language_code': 'en', 'result_type': 're...              0
# 15  {'iso_language_code': 'en', 'result_type': 're...              0
# 16  {'iso_language_code': 'en', 'result_type': 're...              0
# 17  {'iso_language_code': 'en', 'result_type': 're...              0
# 18  {'iso_language_code': 'en', 'result_type': 're...              0
# 21  {'iso_language_code': 'en', 'result_type': 're...              0
# 25  {'iso_language_code': 'en', 'result_type': 're...              0
# 27  {'iso_language_code': 'en', 'result_type': 're...              0
# 30  {'iso_language_code': 'en', 'result_type': 're...              0
# 31  {'iso_language_code': 'en', 'result_type': 're...              0
# 34  {'iso_language_code': 'en', 'result_type': 're...              0
# 35  {'iso_language_code': 'en', 'result_type': 're...              0
# 37  {'iso_language_code': 'en', 'result_type': 're...              0
# 40  {'iso_language_code': 'en', 'result_type': 're...              0
# 42  {'iso_language_code': 'en', 'result_type': 're...              0
# 1   {'iso_language_code': 'en', 'result_type': 're...              0
# 50  {'iso_language_code': 'en', 'result_type': 're...              0
# 56  {'iso_language_code': 'en', 'result_type': 're...              0
# 60  {'iso_language_code': 'en', 'result_type': 're...              0
# 62  {'iso_language_code': 'en', 'result_type': 're...              0
# 99  {'iso_language_code': 'en', 'result_type': 're...              0
#
#                                                  text  truncated
# 91    the guy who plays the piano for his rescue c...      False
# 41   stop what you' doing immediately and look  th...      False
# 19                 \          \               \   ...      False
# 38                                 Cats  world 😼 a1FZ      False
# 85    heartbreaking photo   dog which died chained...      False
# 2             Cats aren'  useless  everyone says 6hGK      False
# 6    retweet  youreally  really    really      rea...      False
# 4                                                9VMa      False
# 57     super-majority  celebration  the Kitten &am...      False
# 20                  Cats are   world  their own  PdFg      False
# 24                                    hover cats E0Kv      False
# 46                  #Our4WordFuture Cats  and kittens      False
# 68   adult black dogs &amp; cats are the least ado...      False
# 39                         its  cats' name TAT ♡♡9FUP      False
# 22    dog with cancer  the  will get radiotherapy ...      False
# 86   😱😭😤This  just one  + pups who were killed  on...      False
# 82   Thankfully  don' rely just  kibble The main m...      False
# 71                                          Wakanda …      False
# 53   "The bond between animals can  mysterious   a...      False
# 87   ‘Spayathon’  happening today and into next we...      False
# 77   PREGNANT MOMMA KITTYI have her   house today ...      False
# 73   👉 Follow @petloveers 🐱 #cat #cats #Kitty #kit...      False
# 58   #MONDAY #DEATHROW quick today posting the dai...      False
# 94   Please support Javier his family and his cats...      False
# 9     there are  cats And the other   heading insi...      False
# 74   🆘🆘🆘🆘🐈💔🐕🚨🚨🚨🚨REQUEST RTS PER @NYCDEATHROWCATS 😿...      False
# 48   PLAYING AND FLIPPING Hope you all have  pawso...      False
# 32                                        Sana Sana …      False
# 8                                         @ cats x7Wl      False
# 3     unfortunate person who loves  book collector...      False
# ..                                                ...        ...
# 79                                             … Hell       True
# 47                                 miss those cats :(      False
# 65                                       Drinks later      False
# 64   case you missed  Cats are Liquid  (finally) c...      False
# 5           you know dogs and cats keep following you      False
# 7    two cats don’ get alone  took this while she ...      False
# 10                you know dogs and cats keep staring      False
# 11  Pet Carrier for Dogs Cats Airline Approved Tra...      False
# 13    love pussy cats Why are you staring   like that      False
# 14                                               cats      False
# 15                                      Cats are dope      False
# 16              you know dogs and cats keep following      False
# 17             Cats everywhere 😂😂🐱🐱#ARMYSelcaDay gE7T      False
# 18   mom really took  dogs blanket and told   put ...      False
# 21             @DarthLux Playing with Cats))) Datings      False
# 25                                 think Winsto… bQoJ       True
# 27  Hbt2  princely loaf #Cats #Cat #Kittens #Kitte...       True
# 30                                      have you here      False
# 31   excited  launch   For  second  thought  would...      False
# 34                Prepper Supplies for Your Cats LkWJ      False
# 35   ' been  few weeks since ' been single Might  ...       True
# 37  Cats are really  adorable They’ cuddly and lov...       True
# 40                                          what got       False
# 42                                 themtheir face uwu      False
# 1                         just wanna touch luke' nose      False
# 50  Did you know the animal members  your family s...       True
# 56  #HappyMonday  know  lot  people post gifs  #do...       True
# 60           wish  had cats  fill this loneliness :")      False
# 62  Ae8E  boy Buttons   frequent blepper #Cats #Ca...       True
# 99                                  cats make   happy      False
#
# [90 rows x 7 columns]

# %%
# Convert the dataframe into text
str_dump = clean_df['text'].to_string()
print(str_dump)
os.remove('tweet_dump.json')
# Out:
# 0     One   favorite Cats  the Cal era #Buckets #BBN...
# 1                           just wanna touch luke' nose
# 2               Cats aren'  useless  everyone says 6hGK
# 3       unfortunate person who loves  book collector...
# 4                                                  9VMa
# 5             you know dogs and cats keep following you
# 6      retweet  youreally  really    really      rea...
# 7      two cats don’ get alone  took this while she ...
# 8                                           @ cats x7Wl
# 9       there are  cats And the other   heading insi...
# 10                  you know dogs and cats keep staring
# 11    Pet Carrier for Dogs Cats Airline Approved Tra...
# 13      love pussy cats Why are you staring   like that
# 14                                                 cats
# 15                                        Cats are dope
# 16                you know dogs and cats keep following
# 17               Cats everywhere 😂😂🐱🐱#ARMYSelcaDay gE7T
# 18     mom really took  dogs blanket and told   put ...
# 19                   \          \               \   ...
# 20                    Cats are   world  their own  PdFg
# 21               @DarthLux Playing with Cats))) Datings
# 22      dog with cancer  the  will get radiotherapy ...
# 23      Shebastill  charge   house  cats😹🐾🐾our grann...
# 24                                      hover cats E0Kv
# 25                                   think Winsto… bQoJ
# 26     With the help  his pet cats and animated frie...
# 27    Hbt2  princely loaf #Cats #Cat #Kittens #Kitte...
# 28          Killem with the cuteness Lol Evil cats QsYC
# 29                                                get …
# 30                                        have you here
# 31     excited  launch   For  second  thought  would...
# 32                                          Sana Sana …
# 33     Listening  John Wayne Gacy @davephantom #horr...
# 34                  Prepper Supplies for Your Cats LkWJ
# 35     ' been  few weeks since ' been single Might  ...
# 36      too  sick  the fat cats  Big Air and their s...
# 37    Cats are really  adorable They’ cuddly and lov...
# 38                                   Cats  world 😼 a1FZ
# 39                           its  cats' name TAT ♡♡9FUP
# 40                                            what got
# 41     stop what you' doing immediately and look  th...
# 42                                   themtheir face uwu
# 43      don’ know why black cats were cursed   perce...
# 44                                  have the their net…
# 46                    #Our4WordFuture Cats  and kittens
# 47                                   miss those cats :(
# 48     PLAYING AND FLIPPING Hope you all have  pawso...
# 49                                            JyUV y9p3
# 50    Did you know the animal members  your family s...
# 51     honestlyi don’ think taylor  touring this sum...
# 52     Timur  the ray  hope for all the stray  cats ...
# 53     "The bond between animals can  mysterious   a...
# 55      Cats have  muscles  each ear  ignore you ☆Fact☆
# 56    #HappyMonday  know  lot  people post gifs  #do...
# 57       super-majority  celebration  the Kitten &am...
# 58     #MONDAY #DEATHROW quick today posting the dai...
# 59                       'Cats #ProCats #SuperBowl m5Te
# 60             wish  had cats  fill this loneliness :")
# 61     wish  have  own room   can allow  cats  sleep...
# 62    Ae8E  boy Buttons   frequent blepper #Cats #Ca...
# 64     case you missed  Cats are Liquid  (finally) c...
# 65                                         Drinks later
# 66      dog  black and white (but mostly black) and ...
# 67     Researchers recently created laser pulses tha...
# 68     adult black dogs &amp; cats are the least ado...
# 69     ran out  canned food for the cats  injured ba...
# 70                         Every cats biggest fear 7csQ
# 71                                            Wakanda …
# 72     whole family loves cats 😂😂  react the same wa...
# 73     👉 Follow @petloveers 🐱 #cat #cats #Kitty #kit...
# 74     🆘🆘🆘🆘🐈💔🐕🚨🚨🚨🚨REQUEST RTS PER @NYCDEATHROWCATS 😿...
# 75    Calling all crazy cat ladies This #giveaway  f...
# 77     PREGNANT MOMMA KITTYI have her   house today ...
# 78     Today’ been  pain  the butt since  woke  can ...
# 79                                               … Hell
# 82     Thankfully  don' rely just  kibble The main m...
# 84    Dogs are mentioned  times  the Bible cats are ...
# 85      heartbreaking photo   dog which died chained...
# 86     😱😭😤This  just one  + pups who were killed  on...
# 87     ‘Spayathon’  happening today and into next we...
# 89                                                 kids
# 90      did    Kevin bakes  loaf  Dis  loaf right   ...
# 91      the guy who plays the piano for his rescue c...
# 92                                                 true
# 94     Please support Javier his family and his cats...
# 95    @domandcats This time last year things were ac...
# 96                               mob reads warrior cats
# 97    Price And Buying Cat’ Eye Gemstone (Lehsunia)X...
# 98                                             Waitress
# 99                                    cats make   happy

# %%
# Import sklearn
from sklearn.feature_extraction.text import CountVectorizer as CV
from sklearn.linear_model import LogisticRegression as LogicReg
from sklearn.metrics import accuracy_score as acc
from sklearn.model_selection import train_test_split as train

# %%
# Get training Data
# From https://github.com/aaronkub/machine-learning-examples/blob/master/imdb-sentiment-analysis/movie_data.tar.gz
# Create Array
reviews_train = []
for line in open(r"C:\Users\Dolcevice\Documents\GitHub\TwitterAggregateSolution\common\Jupyter\Train_Data\aclImdb\movie_data\full_train.txt", 'r',encoding='utf-8'):
    reviews_train.append(line.strip())
reviews_test = []
for line in open(r"C:\Users\Dolcevice\Documents\GitHub\TwitterAggregateSolution\common\Jupyter\Train_Data\aclImdb\movie_data\full_test.txt", 'r',encoding='utf-8'):
    reviews_test.append(line.strip())

# %%
# Clean training Data
REPLACE_NO_SPACE = re.compile("(\.)|(\;)|(\:)|(\!)|(\')|(\?)|(\,)|(\")|(\()|(\))|(\[)|(\])")
REPLACE_WITH_SPACE = re.compile("(<br\s*/><br\s*/>)|(\-)|(\/)")

reviews_train_clean = [REPLACE_NO_SPACE.sub("", line.lower()) for line in reviews_train]
reviews_test_clean = [REPLACE_NO_SPACE.sub("", line.lower()) for line in reviews_test]

# %%
# Vectorize
cv = CV(binary = True)
cv.fit(reviews_train_clean)
X = cv.transform(reviews_train_clean)
X_test = cv.transform(reviews_test_clean)

# %%
# Classifier
target = [1 if i < 12500 else 0 for i in range(25000)]
X_train, X_val, y_train, y_val = train(X, target, train_size = 0.75)

# Use logistic regression on the training data
for c in [0.01, 0.05, 0.25, 0.5, 1]:
    
    lr = LogicReg(C=c)
    lr.fit(X_train, y_train)
    print ("Accuracy for C=%s: %s" % (c, acc(y_val, lr.predict(X_val))))

# %%
# Final Training Model

final_model = LogicReg(C=0.05, n_jobs=-1)
final_model.fit(X, target)
print ("Final Accuracy: %s" % acc(target, final_model.predict(X_test)))

# %%
# Save final model
pickle.dump(final_model, open('final_model.sav', 'wb'))

# %%
# Try the final model
tempOut = open("tempOut.txt", "w", encoding="utf-8")
tempOut.write(str_dump)
tempOut.close()

str_dump_clean = []
with open('tempOut.txt', encoding="utf-8") as my_file:
    for line in my_file:
        str_dump_clean.append(line)
my_file.close()

# Importing and Exporting as text files to turn them into raw string data

print(str_dump_clean)

# Creating a test-ready object

Y_test = cv.transform(str_dump_clean)

result = final_model.predict(Y_test)

result_indf = pd.DataFrame({"Value":result})

print(result_indf)

# %%
# Calculate Meaningful Data
len(result_indf.index)
result_pos = result_indf.iloc[0: int(len(result_indf.index) / 2)] # Top half of the array is related to positive sentiment
print(result_pos.mean(axis=0))

pos_mean = result_pos.mean(axis=0)

result_neg = result_indf.iloc[int(len(result_indf.index) / 2): int(len(result_indf.index))] # Bottom half of the array is related to 
# negative sentiment
print(result_neg.mean(axis=0))

neg_mean = result_neg.mean(axis=0)

# %%
# Comparison
pos_per = pos_mean / (pos_mean + neg_mean)
neg_per = neg_mean / (pos_mean + neg_mean)

dif = (pos_per - neg_per) * 100
difference = dif.to_string()

diff = re.findall("-\d+\.\d+" or "\d+\.\d+", difference)
difff = diff[0]

float_dif = float(difff)
print (float_dif)

# %%
# In words:

if  float_dif >= 50.0:
    status = "Greatly Favored"
elif float_dif >= 25.0:
    status = "Significantly Favored"
elif float_dif >= 0.0:
    status = "Slightly Favored"
elif float_dif < 0.0:
    status = "Slightly Unfavored"
elif float_dif <= -25.0:
    status = "Significantly Unfavored"
elif float_dif <= -50.0:
    status = "Heavily Unfavored"    
else:
    status = "Error"

print("************************************************************")
print("Twitter's perception of " + s_query + " right now is: " + status + ", by " + str(abs(float_dif)) + "%.")
